# %% [raw]
# #  1.Take 2 images and combine it to form a single image
# #  2.Take 2 images, crop some part of both the images and swap them.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
pic = cv2.imread(r'C:\Users\vishw\Documents\Untitled Folder 1\img_1.jpg')

# %%
plt.title('Orignal')
plt.imshow(pic)

# %%
crop_image = pic[0:200, 0:250]

# %%
plt.title('Crop')
plt.imshow(crop_image)

# %%
pic2 = cv2.imread(r'C:\Users\vishw\Documents\Untitled Folder 1\img_2.jpg')

# %%
plt.title('Orignal')
plt.imshow(pic2)

# %%
crop2 = pic2[0:200, 0:250]

# %%
plt.title('cropped')
plt.imshow(crop2)

# %%
merge = np.hstack((crop_image, crop2))

# %%
plt.imshow(merge)
